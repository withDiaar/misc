# %% [markdown]
# <a href="https://colab.research.google.com/github/withDiaar/misc/blob/main/AIFaceDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import cv2
image = cv2.imread("bean.jpg")
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
model= cv2.CascadeClassifier("model.xml")
face=model.detectMultiScale(image)
x=face[0][0]
y=face[0][1]
a=face[0][2]
b=face[0][3]
image=cv2.rectangle(image, (x,y) , (x+a,y+b), (209, 50, 2),3)
plt.imshow(image)
